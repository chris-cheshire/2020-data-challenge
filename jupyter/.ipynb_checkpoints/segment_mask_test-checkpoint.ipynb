# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def rotate_bound(image, angle):
    # grab the dimensions of the image and then determine the
    # center
    (h, w) = image.shape[:2]
    (cX, cY) = (w // 2, h // 2)
    # grab the rotation matrix (applying the negative of the
    # angle to rotate clockwise), then grab the sine and cosine
    # (i.e., the rotation components of the matrix)
    M = cv2.getRotationMatrix2D((cX, cY), -angle, 1.0)
    cos = np.abs(M[0, 0])
    sin = np.abs(M[0, 1])
    # compute the new bounding dimensions of the image
    nW = int((h * sin) + (w * cos))
    nH = int((h * cos) + (w * sin))
    # adjust the rotation matrix to take into account translation
    M[0, 2] += (nW / 2) - cX
    M[1, 2] += (nH / 2) - cY
    # perform the actual rotation and return the image
    return cv2.warpAffine(image, M, (nW, nH))

# %%
mask_path = '../data/'
frames_path = '../data/frames/C59_L1_t0'

# %%
angle_increment = 1
min_angle = 0
max_angle = 90

# %%
img_orig = cv2.imread(os.path.join(frames_path,'frame-0.jpg'),0)
img_mask = cv2.imread(os.path.join(mask_path,'mask-1-cropped.jpg'),0)

# %%
#print(img_mask.shape)

#scale_percent = 60 # percent of original size
#width = int(img_mask.shape[1] * scale_percent / 100)
#height = int(img_mask.shape[0] * scale_percent / 100)
#dim = (width, height)
# resize image
#img_mask = cv2.resize(img_mask, dim, interpolation = cv2.INTER_AREA)

#print(img_mask.shape)

# %%
img_blur = cv2.medianBlur(img_orig,7)
img_thresh = cv2.adaptiveThreshold(img_blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,11,2)
img_thresh_inv = cv2.bitwise_not(img_thresh)
ret, img_mask = cv2.threshold(img_mask, 10, 255, cv2.THRESH_BINARY)

# %%
angle = min_angle
images = []
scores = []
positions = []

rows,cols = img_orig.shape
print("Main image has {0} rows and {1} cols".format(rows,cols))

while angle <= max_angle:
    
    # Rotate mask and log
    img_mask_rotated = rotate_bound(img_mask, angle)
    mask_rows,mask_cols = img_mask_rotated.shape
    print("Current rotation {2} degrees has {0} rows and {1} cols".format(mask_rows,mask_cols,angle))
    
    # Pass image over
    for i in range(rows):
        if i + mask_rows > rows:
            continue
        for j in range(cols):
            if j + mask_cols > cols:
                continue
            
            # Create roi
            roi = img_thresh_inv[i:mask_rows+i,j:mask_cols+j]
            
            #print(img_mask_rotated.shape)
            #print(roi.shape)
            #print([i,j,angle])
            
            # Mask with mask
            masked = cv2.bitwise_and(roi,img_mask_rotated)
            
            # Save image and scores
            images.append(masked)
            scores.append(masked.sum())
            positions.append([i,j,angle])
            
    angle += angle_increment
            
print("Complete")
    
#plot_count = len(images)
#for i in range(plot_count):
#    plt.figure(figsize=(100,100))
#    plt.subplot(plot_count,1,i+1),plt.imshow(images[i],'gray')
#    plt.title(scores[i])
#    plt.xticks([]),plt.yticks([])
#    plt.show()
# Out:
# Main image has 128 rows and 128 cols
# Current rotation 0 degrees has 15 rows and 65 cols
# Current rotation 1 degrees has 16 rows and 65 cols
# Current rotation 2 degrees has 17 rows and 65 cols
# Current rotation 3 degrees has 18 rows and 65 cols
# Current rotation 4 degrees has 19 rows and 65 cols
# Current rotation 5 degrees has 20 rows and 66 cols
# Current rotation 6 degrees has 21 rows and 66 cols
# Current rotation 7 degrees has 22 rows and 66 cols
# Current rotation 8 degrees has 23 rows and 66 cols
# Current rotation 9 degrees has 24 rows and 66 cols
# Current rotation 10 degrees has 26 rows and 66 cols
# Current rotation 11 degrees has 27 rows and 66 cols
# Current rotation 12 degrees has 28 rows and 66 cols
# Current rotation 13 degrees has 29 rows and 66 cols
# Current rotation 14 degrees has 30 rows and 66 cols
# Current rotation 15 degrees has 31 rows and 66 cols
# Current rotation 16 degrees has 32 rows and 66 cols
# Current rotation 17 degrees has 33 rows and 66 cols
# Current rotation 18 degrees has 34 rows and 66 cols
# Current rotation 19 degrees has 35 rows and 66 cols
# Current rotation 20 degrees has 36 rows and 66 cols
# Current rotation 21 degrees has 37 rows and 66 cols
# Current rotation 22 degrees has 38 rows and 65 cols
# Current rotation 23 degrees has 39 rows and 65 cols
# Current rotation 24 degrees has 40 rows and 65 cols
# Current rotation 25 degrees has 41 rows and 65 cols
# Current rotation 26 degrees has 41 rows and 64 cols
# Current rotation 27 degrees has 42 rows and 64 cols
# Current rotation 28 degrees has 43 rows and 64 cols
# Current rotation 29 degrees has 44 rows and 64 cols
# Current rotation 30 degrees has 45 rows and 63 cols
# Current rotation 31 degrees has 46 rows and 63 cols
# Current rotation 32 degrees has 47 rows and 63 cols
# Current rotation 33 degrees has 47 rows and 62 cols
# Current rotation 34 degrees has 48 rows and 62 cols
# Current rotation 35 degrees has 49 rows and 61 cols
# Current rotation 36 degrees has 50 rows and 61 cols
# Current rotation 37 degrees has 51 rows and 60 cols
# Current rotation 38 degrees has 51 rows and 60 cols
# Current rotation 39 degrees has 52 rows and 59 cols
# Current rotation 40 degrees has 53 rows and 59 cols
# Current rotation 41 degrees has 53 rows and 58 cols
# Current rotation 42 degrees has 54 rows and 58 cols
# Current rotation 43 degrees has 55 rows and 57 cols
# Current rotation 44 degrees has 55 rows and 57 cols
# Current rotation 45 degrees has 56 rows and 56 cols
# Current rotation 46 degrees has 57 rows and 55 cols
# Current rotation 47 degrees has 57 rows and 55 cols
# Current rotation 48 degrees has 58 rows and 54 cols
# Current rotation 49 degrees has 58 rows and 53 cols
# Current rotation 50 degrees has 59 rows and 53 cols
# Current rotation 51 degrees has 59 rows and 52 cols
# Current rotation 52 degrees has 60 rows and 51 cols
# Current rotation 53 degrees has 60 rows and 51 cols
# Current rotation 54 degrees has 61 rows and 50 cols
# Current rotation 55 degrees has 61 rows and 49 cols
# Current rotation 56 degrees has 62 rows and 48 cols
# Current rotation 57 degrees has 62 rows and 47 cols
# Current rotation 58 degrees has 63 rows and 47 cols
# Current rotation 59 degrees has 63 rows and 46 cols
# Current rotation 60 degrees has 63 rows and 45 cols
# Current rotation 61 degrees has 64 rows and 44 cols
# Current rotation 62 degrees has 64 rows and 43 cols
# Current rotation 63 degrees has 64 rows and 42 cols
# Current rotation 64 degrees has 64 rows and 41 cols
# Current rotation 65 degrees has 65 rows and 41 cols
# Current rotation 66 degrees has 65 rows and 40 cols
# Current rotation 67 degrees has 65 rows and 39 cols
# Current rotation 68 degrees has 65 rows and 38 cols
# Current rotation 69 degrees has 66 rows and 37 cols
# Current rotation 70 degrees has 66 rows and 36 cols
# Current rotation 71 degrees has 66 rows and 35 cols
# Current rotation 72 degrees has 66 rows and 34 cols
# Current rotation 73 degrees has 66 rows and 33 cols
# Current rotation 74 degrees has 66 rows and 32 cols
# Current rotation 75 degrees has 66 rows and 31 cols
# Current rotation 76 degrees has 66 rows and 30 cols
# Current rotation 77 degrees has 66 rows and 29 cols
# Current rotation 78 degrees has 66 rows and 28 cols
# Current rotation 79 degrees has 66 rows and 27 cols
# Current rotation 80 degrees has 66 rows and 26 cols
# Current rotation 81 degrees has 66 rows and 24 cols
# Current rotation 82 degrees has 66 rows and 23 cols
# Current rotation 83 degrees has 66 rows and 22 cols
# Current rotation 84 degrees has 66 rows and 21 cols
# Current rotation 85 degrees has 66 rows and 20 cols
# Current rotation 86 degrees has 65 rows and 19 cols
# Current rotation 87 degrees has 65 rows and 18 cols
# Current rotation 88 degrees has 65 rows and 17 cols
# Current rotation 89 degrees has 65 rows and 16 cols
# Current rotation 90 degrees has 65 rows and 15 cols
# Complete

# %%
max_score = np.max(scores)
max_index = np.argmax(scores)
best_position = positions[max_index]

print("Numer of images scored: ", str(len(images)))
print("Max score: ", str(max_score))
print("Max index: ", str(max_index))
print("Position of max score: ", best_position)

# Create rois
img_mask_rotated = rotate_bound(img_mask, best_position[2])
mask_rows,mask_cols = img_mask_rotated.shape

#print(img_mask_rotated.shape)
#print(img_orig.shape)

roi1 = img_orig[best_position[0]:mask_rows+best_position[0],best_position[1]:mask_cols+best_position[1]]
roi2 = img_thresh_inv[best_position[0]:mask_rows+best_position[0],best_position[1]:mask_cols+best_position[1]]

#print(img_mask_rotated.shape)
#print(roi1.shape)
#print(roi2.shape)

masked = cv2.bitwise_and(roi1,img_mask_rotated)

plt.figure()
plt.xticks([]),plt.yticks([])
plt.imshow(img_orig,'gray')
plt.show()

plt.figure()
plt.xticks([]),plt.yticks([])
plt.imshow(img_mask_rotated,'gray')
plt.show()

plt.figure()
plt.xticks([]),plt.yticks([])
plt.imshow(roi2,'gray')
plt.show()

plt.figure()
plt.xticks([]),plt.yticks([])
plt.imshow(roi1,'gray')
plt.show()

plt.figure()
plt.xticks([]),plt.yticks([])
plt.imshow(masked,'gray')
plt.show()
# Out:
# Numer of images scored:  544679
# Max score:  83807
# Max index:  238889
# Position of max score:  [18, 41, 39]
